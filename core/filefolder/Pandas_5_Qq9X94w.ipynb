# %%
#loc vs iloc

loc --> name
stop value - included

iloc --> integer location/number
stop value -- excluded

# %%
import pandas as pd

# %%
df = pd.read_csv('hotel_booking.csv')

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.set_index('arrival_date_month',inplace=True)

# %%
df.loc['August']
# Out:
#                            hotel  is_canceled  lead_time  arrival_date_year  \
# arrival_date_month
# August              Resort Hotel            0        129               2015
# August              Resort Hotel            1         84               2015
# August              Resort Hotel            1         84               2015
# August              Resort Hotel            1         89               2015
# August              Resort Hotel            1         10               2015
# ...                          ...          ...        ...                ...
# August                City Hotel            0         23               2017
# August                City Hotel            0        102               2017
# August                City Hotel            0         34               2017
# August                City Hotel            0        109               2017
# August                City Hotel            0        205               2017
#
# ...

# %%
August -> total number of booking

# %%
df.loc['August',['hotel','lead_time','stays_in_week_nights']]['stays_in_week_nights'].sum()
# Out:
# 39361

# %%
sum(df.loc['August']['arrival_date_year']==2017)
# Out:
# 4925

# %%
df.loc['August']['arrival_date_year'].value_counts()
# Out:
# 2016    5063
# 2017    4925
# 2015    3889
# Name: arrival_date_year, dtype: int64

# %%
df[(df.loc['May']['reservation_status']=='Canceled')]
# Out:
# <ipython-input-48-83872343e3d4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df.loc['May']['reservation_status']=='Canceled')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-83872343e3d4> in <module>
# ----> 1 df[(df.loc['May']['reservation_status']=='Canceled')]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
df.reset_index(inplace=True)

# %%
Month --> May and Res --> Canceled

# %%
df[(df['reservation_status']=='Canceled') & (df['arrival_date_month']=='May')].shape[0]
# Out:
# 4545

# %%
df[df['arrival_date_month']=='March']['reservation_status'].value_counts()[1]
# Out:
# 3027

# %%
df[df['reservation_status']=='Canceled']['arrival_date_month'].value_counts()
# Out:
# August       5147
# July         4646
# May          4545
# June         4451
# April        4447
# October      4173
# September    4049
# March        3027
# February     2467
# December     2289
# November     2044
# January      1732
# Name: arrival_date_month, dtype: int64

# %%
Pandas ---> SQL --> Query

# %%
df.query("reservation_status=='Canceled'")
# Out:
#        arrival_date_month         hotel  is_canceled  lead_time  \
# 8                    July  Resort Hotel            1         85
# 9                    July  Resort Hotel            1         75
# 10                   July  Resort Hotel            1         23
# 27                   July  Resort Hotel            1         60
# 32                   July  Resort Hotel            1         96
# ...                   ...           ...          ...        ...
# 107997                May    City Hotel            1         13
# 108000                May    City Hotel            1         13
# 110280              April    City Hotel            1        132
# 111355               June    City Hotel            1          4
# 111924                May    City Hotel            1          7
#
#         arrival_date_year  arrival_date_week_number  \
# 8                    2015                        27
# 9                    2015                        27
# ...

# %%
excel --> heavy --> fast --> back end -- numpy --> 1B --

# %%
logic --> Programming

# %%
eBay --> 1 -- 10min

# %%
df['arrival_date_week_number'].sum()
# Out:
# 3243250

# %%
df['arrival_date_week_number'].std()
# Out:
# 13.605138355498454

# %%
df['arrival_date_week_number'].mean()
# Out:
# 27.16517296255968

# %%
df.transpose()
# Out:
#                                                      0       \
# arrival_date_month                                     July
# hotel                                          Resort Hotel
# is_canceled                                               0
# lead_time                                               342
# arrival_date_year                                      2015
# arrival_date_week_number                                 27
# arrival_date_day_of_month                                 1
# stays_in_weekend_nights                                   0
# stays_in_week_nights                                      0
# adults                                                    2
# children                                                0.0
# babies                                                    0
# meal                                                     BB
# country                                                 PRT
# market_segment                                       Direct
# ...

# %%
df.melt()
# Out:
#                    variable             value
# 0        arrival_date_month              July
# 1        arrival_date_month              July
# 2        arrival_date_month              July
# 3        arrival_date_month              July
# 4        arrival_date_month              July
# ...                     ...               ...
# 4298035         credit_card  ************8647
# 4298036         credit_card  ************4333
# 4298037         credit_card  ************1821
# 4298038         credit_card  ************7860
# 4298039         credit_card  ************4482
#
# [4298040 rows x 2 columns]

# %%
Pandas --> DEV+DE+DA+ML+DS+AI+AUTO+TEST

# %%
df
# Out:
#        arrival_date_month         hotel  is_canceled  lead_time  \
# 0                    July  Resort Hotel            0        342
# 1                    July  Resort Hotel            0        737
# 2                    July  Resort Hotel            0          7
# 3                    July  Resort Hotel            0         13
# 4                    July  Resort Hotel            0         14
# ...                   ...           ...          ...        ...
# 119385             August    City Hotel            0         23
# 119386             August    City Hotel            0        102
# 119387             August    City Hotel            0         34
# 119388             August    City Hotel            0        109
# 119389             August    City Hotel            0        205
#
#         arrival_date_year  arrival_date_week_number  \
# 0                    2015                        27
# 1                    2015                        27
# ...

# %%
df
# Out:
#        arrival_date_month         hotel  is_canceled  lead_time  \
# 0                    July  Resort Hotel            0        342
# 1                    July  Resort Hotel            0        737
# 2                    July  Resort Hotel            0          7
# 3                    July  Resort Hotel            0         13
# 4                    July  Resort Hotel            0         14
# ...                   ...           ...          ...        ...
# 119385             August    City Hotel            0         23
# 119386             August    City Hotel            0        102
# 119387             August    City Hotel            0         34
# 119388             August    City Hotel            0        109
# 119389             August    City Hotel            0        205
#
#         arrival_date_year  arrival_date_week_number  \
# 0                    2015                        27
# 1                    2015                        27
# ...

# %%
df['lead_time'].mean()
# Out:
# 104.01141636652986

# %%
df[df['lead_time']>df['lead_time'].mean()]
# Out:
#        arrival_date_month         hotel  is_canceled  lead_time  \
# 0                    July  Resort Hotel            0        342
# 1                    July  Resort Hotel            0        737
# 24                   July  Resort Hotel            0        127
# 30                   July  Resort Hotel            0        118
# 44                   July  Resort Hotel            0        107
# ...                   ...           ...          ...        ...
# 119381             August    City Hotel            0        188
# 119382             August    City Hotel            0        135
# 119383             August    City Hotel            0        164
# 119388             August    City Hotel            0        109
# 119389             August    City Hotel            0        205
#
#         arrival_date_year  arrival_date_week_number  \
# 0                    2015                        27
# 1                    2015                        27
# ...

# %%
df[df['adults']>2]['arrival_date_month'].value_counts()
# Out:
# August       1288
# July         1203
# April         613
# June          570
# May           463
# March         441
# October       366
# February      352
# September     335
# December      320
# January       205
# November      124
# Name: arrival_date_month, dtype: int64

# %%
df['customer_type'].unique()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
df.sort_values(by='lead_time',ascending=False)
# Out:
#       arrival_date_month         hotel  is_canceled  lead_time  \
# 1                   July  Resort Hotel            0        737
# 4182            February  Resort Hotel            0        709
# 65240              March    City Hotel            1        629
# 65249              March    City Hotel            1        629
# 65245              March    City Hotel            1        629
# ...                  ...           ...          ...        ...
# 85725              March    City Hotel            0          0
# 85726              March    City Hotel            0          0
# 85758              March    City Hotel            0          0
# 85759              March    City Hotel            0          0
# 20017            January  Resort Hotel            0          0
#
#        arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  \
# 1                   2015                        27                          1
# ...

# %%
df[df['lead_time']>df['lead_time'].mean()].sort_values(by='lead_time',ascending=False)
# Out:
#       arrival_date_month         hotel  is_canceled  lead_time  \
# 1                   July  Resort Hotel            0        737
# 4182            February  Resort Hotel            0        709
# 65240              March    City Hotel            1        629
# 65251              March    City Hotel            1        629
# 65244              March    City Hotel            1        629
# ...                  ...           ...          ...        ...
# 44817            October    City Hotel            1        105
# 68438                May    City Hotel            1        105
# 68116                May    City Hotel            1        105
# 44816            October    City Hotel            1        105
# 36397                May  Resort Hotel            0        105
#
#        arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  \
# 1                   2015                        27                          1
# ...

# %%
df.sort_values(by='arrival_date_month')
# Out:
#       arrival_date_month         hotel  is_canceled  lead_time  \
# 87641              April    City Hotel            0         60
# 87091              April    City Hotel            0         26
# 87090              April    City Hotel            0          7
# 87089              April    City Hotel            0         21
# 87088              April    City Hotel            0         64
# ...                  ...           ...          ...        ...
# 8398           September  Resort Hotel            1        347
# 8397           September  Resort Hotel            0        542
# 8396           September  Resort Hotel            1         19
# 8404           September  Resort Hotel            1        339
# 98043          September    City Hotel            0        116
#
#        arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  \
# 87641               2016                        17                         18
# ...

# %%
# connection string --> Pandas --> Database --> AWS cloud

# data transfer

# connection termination

# %%
def username(e):
    u = e.split('@')[0]
    return u

# %%
apply --> function  complete df or single col
map

# %%
p = {'a':[10,50,64,34],
    'b':[34,75,34,8],
    'c':[34,87,34,9]}

# %%
df1 = pd.DataFrame(p)

# %%
df1.apply()
# Out:
#     a   b   c
# 0  10  34  34
# 1  50  75  87
# 2  64  34  34
# 3  34   8   9

# %%
def test(v):
    return v*2

# %%
df1.apply(test)
# Out:
#      a    b    c
# 0   20   68   68
# 1  100  150  174
# 2  128   68   68
# 3   68   16   18

# %%
df1['t']= df1['c'].apply(test)

# %%
df1
# Out:
#     a   b   c    t
# 0  10  34  34   68
# 1  50  75  87  174
# 2  64  34  34   68
# 3  34   8   9   18

# %%
df['username'] = df['email'].apply(username)

# %%
df
# Out:
#        arrival_date_month         hotel  is_canceled  lead_time  \
# 0                    July  Resort Hotel            0        342
# 1                    July  Resort Hotel            0        737
# 2                    July  Resort Hotel            0          7
# 3                    July  Resort Hotel            0         13
# 4                    July  Resort Hotel            0         14
# ...                   ...           ...          ...        ...
# 119385             August    City Hotel            0         23
# 119386             August    City Hotel            0        102
# 119387             August    City Hotel            0         34
# 119388             August    City Hotel            0        109
# 119389             August    City Hotel            0        205
#
#         arrival_date_year  arrival_date_week_number  \
# 0                    2015                        27
# 1                    2015                        27
# ...
